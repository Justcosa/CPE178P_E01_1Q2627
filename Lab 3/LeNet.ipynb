# %% [markdown]
# LeNet

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import os
import matplotlib.pyplot as plt

# %%
# Data preprocessing
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


# Download and load the CIFAR-10 dataset.
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=1)


testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False, num_workers=1)
# Out:
# 100%|██████████| 170M/170M [39:17<00:00, 72.3kB/s]

# %%
# Display the images.
dataiter = iter(trainloader)
images, labels = next(dataiter)
# Create a grid to display images.
imshow = torchvision.utils.make_grid(images)


# Convert to a NumPy array and remove normalization.
imshow = imshow.numpy().transpose((1, 2, 0))


# Show images.
plt.imshow(imshow)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].

# %%
# Define the LeNet network structure.
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()  # Call the constructor of the parent class nn.Module.
        # For the first convolutional layer, the number of input channels is 3, the number of output channels is 6, and the size of the convolution kernel is 5 x 5.
        self.conv1 = nn.Conv2d(3, 6, kernel_size=5)
        # For the second convolutional layer, the number of input channels is 6, the number of output channels is 16, and the size of the convolution kernel is 5 x 5.
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        # For the first fully-connected layer, the number of input features is 16 x 5 x 5, and the number of output features is 120.
        self.fc1 = nn.Linear(16*5*5, 120)
        # For the second fully-connected layer, the number of input features is 120, and the number of output features is 84.
        self.fc2 = nn.Linear(120, 84)
        # For the third fully-connected layer (output layer), the number of input features is 84, and the number of output features is 10.
        self.fc3 = nn.Linear(84, 10)
 
    def forward(self, x):
        x = torch.tanh(self.conv1(x))
        # Perform 2 x 2 max pooling on x.
        x = torch.max_pool2d(x, 2)
        # x passes through the second convolutional layer, and then applies the tanh activation function.
        x = torch.tanh(self.conv2(x))
        # Perform 2 x 2 max pooling on x.
        x = torch.max_pool2d(x, 2)
        # Flatten x into a one-dimensional vector and input it to the fully-connected layer. The size is (batch_size, 16 x 5 x 5).
        x = x.view(-1, 16*5*5)
        x = torch.tanh(self.fc1(x))
        # x passes through the second fully-connected layer and then applies the tanh activation function.
        x = torch.tanh(self.fc2(x))
        # x passes through the third fully-connected layer (output layer). Generally, the activation function is not used here because the output value may be used for tasks such as classification.
        x = self.fc3(x)
        return x
 
# Instantiate the LeNet network.
net = LeNet()
net.parameters # View the model parameters.
# Out:
# <bound method Module.parameters of LeNet(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )>

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
# Check whether there are trained parameters to load.
if os.path.isfile("cifar10.pth"): 
    net.load_state_dict(torch.load("cifar10.pth"))
# Store the loss value.
loss_history = []


# Train the network.
for epoch in range(50): # 50 epochs
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data


        optimizer.zero_grad()


        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


        running_loss += loss.item()
        if i % 200 == 199: 
            print(f'[Epoch: {epoch + 1}, Batch: {i + 1}] loss: {running_loss / 200:.3f}')
            running_loss = 0.0
        
        # Record the loss value.
        loss_history.append(loss.item())


print('Finished Training')
# Out:
# [Epoch: 1, Batch: 200] loss: 2.299
# [Epoch: 1, Batch: 400] loss: 2.248
# [Epoch: 1, Batch: 600] loss: 2.111
# [Epoch: 2, Batch: 200] loss: 2.009
# [Epoch: 2, Batch: 400] loss: 1.968
# [Epoch: 2, Batch: 600] loss: 1.936
# [Epoch: 3, Batch: 200] loss: 1.871
# [Epoch: 3, Batch: 400] loss: 1.855
# [Epoch: 3, Batch: 600] loss: 1.805
# [Epoch: 4, Batch: 200] loss: 1.721
# [Epoch: 4, Batch: 400] loss: 1.697
# [Epoch: 4, Batch: 600] loss: 1.674
# [Epoch: 5, Batch: 200] loss: 1.606
# [Epoch: 5, Batch: 400] loss: 1.600
# [Epoch: 5, Batch: 600] loss: 1.582
# [Epoch: 6, Batch: 200] loss: 1.539
# [Epoch: 6, Batch: 400] loss: 1.539
# [Epoch: 6, Batch: 600] loss: 1.502
# [Epoch: 7, Batch: 200] loss: 1.471
# [Epoch: 7, Batch: 400] loss: 1.455
# [Epoch: 7, Batch: 600] loss: 1.454
# [Epoch: 8, Batch: 200] loss: 1.411
# [Epoch: 8, Batch: 400] loss: 1.408
# [Epoch: 8, Batch: 600] loss: 1.409
# [Epoch: 9, Batch: 200] loss: 1.373
# [Epoch: 9, Batch: 400] loss: 1.360
# [Epoch: 9, Batch: 600] loss: 1.361
# [Epoch: 10, Batch: 200] loss: 1.338
# [Epoch: 10, Batch: 400] loss: 1.336
# [Epoch: 10, Batch: 600] loss: 1.315
# [Epoch: 11, Batch: 200] loss: 1.305
# [Epoch: 11, Batch: 400] loss: 1.300
# [Epoch: 11, Batch: 600] loss: 1.287
# [Epoch: 12, Batch: 200] loss: 1.281
# [Epoch: 12, Batch: 400] loss: 1.272
# [Epoch: 12, Batch: 600] loss: 1.271
# [Epoch: 13, Batch: 200] loss: 1.268
# [Epoch: 13, Batch: 400] loss: 1.243
# [Epoch: 13, Batch: 600] loss: 1.250
# [Epoch: 14, Batch: 200] loss: 1.225
# [Epoch: 14, Batch: 400] loss: 1.225
# [Epoch: 14, Batch: 600] loss: 1.214
# [Epoch: 15, Batch: 200] loss: 1.207
# [Epoch: 15, Batch: 400] loss: 1.193
# [Epoch: 15, Batch: 600] loss: 1.203
# [Epoch: 16, Batch: 200] loss: 1.178
# [Epoch: 16, Batch: 400] loss: 1.182
# [Epoch: 16, Batch: 600] loss: 1.191
# [Epoch: 17, Batch: 200] loss: 1.166
# [Epoch: 17, Batch: 400] loss: 1.163
# [Epoch: 17, Batch: 600] loss: 1.153
# [Epoch: 18, Batch: 200] loss: 1.143
# [Epoch: 18, Batch: 400] loss: 1.129
# [Epoch: 18, Batch: 600] loss: 1.138
# [Epoch: 19, Batch: 200] loss: 1.125
# [Epoch: 19, Batch: 400] loss: 1.115
# [Epoch: 19, Batch: 600] loss: 1.130
# [Epoch: 20, Batch: 200] loss: 1.095
# [Epoch: 20, Batch: 400] loss: 1.110
# [Epoch: 20, Batch: 600] loss: 1.131
# [Epoch: 21, Batch: 200] loss: 1.099
# [Epoch: 21, Batch: 400] loss: 1.083
# [Epoch: 21, Batch: 600] loss: 1.092
# [Epoch: 22, Batch: 200] loss: 1.082
# [Epoch: 22, Batch: 400] loss: 1.084
# [Epoch: 22, Batch: 600] loss: 1.079
# [Epoch: 23, Batch: 200] loss: 1.051
# [Epoch: 23, Batch: 400] loss: 1.062
# [Epoch: 23, Batch: 600] loss: 1.076
# [Epoch: 24, Batch: 200] loss: 1.037
# [Epoch: 24, Batch: 400] loss: 1.070
# [Epoch: 24, Batch: 600] loss: 1.062
# [Epoch: 25, Batch: 200] loss: 1.044
# [Epoch: 25, Batch: 400] loss: 1.049
# [Epoch: 25, Batch: 600] loss: 1.039
# [Epoch: 26, Batch: 200] loss: 1.043
# [Epoch: 26, Batch: 400] loss: 1.028
# [Epoch: 26, Batch: 600] loss: 1.021
# [Epoch: 27, Batch: 200] loss: 1.023
# [Epoch: 27, Batch: 400] loss: 1.018
# [Epoch: 27, Batch: 600] loss: 1.003
# [Epoch: 28, Batch: 200] loss: 1.005
# [Epoch: 28, Batch: 400] loss: 1.006
# [Epoch: 28, Batch: 600] loss: 0.996
# [Epoch: 29, Batch: 200] loss: 0.991
# [Epoch: 29, Batch: 400] loss: 0.989
# [Epoch: 29, Batch: 600] loss: 0.995
# [Epoch: 30, Batch: 200] loss: 0.984
# [Epoch: 30, Batch: 400] loss: 0.984
# [Epoch: 30, Batch: 600] loss: 0.981
# [Epoch: 31, Batch: 200] loss: 0.970
# [Epoch: 31, Batch: 400] loss: 0.980
# [Epoch: 31, Batch: 600] loss: 0.977
# [Epoch: 32, Batch: 200] loss: 0.961
# [Epoch: 32, Batch: 400] loss: 0.973
# [Epoch: 32, Batch: 600] loss: 0.968
# [Epoch: 33, Batch: 200] loss: 0.952
# [Epoch: 33, Batch: 400] loss: 0.954
# [Epoch: 33, Batch: 600] loss: 0.959
# [Epoch: 34, Batch: 200] loss: 0.934
# [Epoch: 34, Batch: 400] loss: 0.944
# [Epoch: 34, Batch: 600] loss: 0.941
# [Epoch: 35, Batch: 200] loss: 0.943
# [Epoch: 35, Batch: 400] loss: 0.925
# [Epoch: 35, Batch: 600] loss: 0.938
# [Epoch: 36, Batch: 200] loss: 0.928
# [Epoch: 36, Batch: 400] loss: 0.932
# [Epoch: 36, Batch: 600] loss: 0.923
# [Epoch: 37, Batch: 200] loss: 0.910
# [Epoch: 37, Batch: 400] loss: 0.925
# [Epoch: 37, Batch: 600] loss: 0.911
# [Epoch: 38, Batch: 200] loss: 0.897
# [Epoch: 38, Batch: 400] loss: 0.926
# [Epoch: 38, Batch: 600] loss: 0.905
# [Epoch: 39, Batch: 200] loss: 0.898
# [Epoch: 39, Batch: 400] loss: 0.905
# [Epoch: 39, Batch: 600] loss: 0.906
# [Epoch: 40, Batch: 200] loss: 0.888
# [Epoch: 40, Batch: 400] loss: 0.901
# [Epoch: 40, Batch: 600] loss: 0.895
# [Epoch: 41, Batch: 200] loss: 0.886
# [Epoch: 41, Batch: 400] loss: 0.878
# [Epoch: 41, Batch: 600] loss: 0.875
# [Epoch: 42, Batch: 200] loss: 0.872
# [Epoch: 42, Batch: 400] loss: 0.870
# [Epoch: 42, Batch: 600] loss: 0.882
# [Epoch: 43, Batch: 200] loss: 0.851
# [Epoch: 43, Batch: 400] loss: 0.878
# [Epoch: 43, Batch: 600] loss: 0.857
# [Epoch: 44, Batch: 200] loss: 0.850
# [Epoch: 44, Batch: 400] loss: 0.854
# [Epoch: 44, Batch: 600] loss: 0.855
# [Epoch: 45, Batch: 200] loss: 0.856
# [Epoch: 45, Batch: 400] loss: 0.838
# [Epoch: 45, Batch: 600] loss: 0.847
# [Epoch: 46, Batch: 200] loss: 0.832
# [Epoch: 46, Batch: 400] loss: 0.841
# [Epoch: 46, Batch: 600] loss: 0.838
# [Epoch: 47, Batch: 200] loss: 0.829
# [Epoch: 47, Batch: 400] loss: 0.824
# [Epoch: 47, Batch: 600] loss: 0.827
# [Epoch: 48, Batch: 200] loss: 0.815
# [Epoch: 48, Batch: 400] loss: 0.817
# [Epoch: 48, Batch: 600] loss: 0.831
# [Epoch: 49, Batch: 200] loss: 0.810
# [Epoch: 49, Batch: 400] loss: 0.820
# [Epoch: 49, Batch: 600] loss: 0.812
# [Epoch: 50, Batch: 200] loss: 0.819
# [Epoch: 50, Batch: 400] loss: 0.793
# [Epoch: 50, Batch: 600] loss: 0.809
# Finished Training

# %%
# Draw the loss curve.
plt.plot(loss_history)
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.title('Loss over Training Batches')
plt.show()

# %%
# Test the performance of the network with the test set.
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()


print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f}%')
# Out:
# Accuracy of the network on the 10000 test images: 64.80%
